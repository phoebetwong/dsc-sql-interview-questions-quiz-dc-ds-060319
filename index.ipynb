# %% [markdown]
# # SQL Interview Questions  - Quiz
#
# ## Introduction
#
# In this lesson, we'll go through a short quiz containing the types of questions about SQL and relational databases that you can expect to see in an interview.
#
#
#
# ## SQL Interview Questions
#
# This quiz contains questions on topics you can expect to see in an interview pertaining to SQL and Relational Databases. Some of them are multiple choice, while some are short answer. For these short answer questions, double click on the Jupyter Notebook and type your answer below the line.
#
# ## Question 1
#
# what are the 4 main datatypes in SQLite3? Can we use other common types from other kinds of SQL?
#
# Type your answer below this line:
# text, integer, real, and blob. Yes SQLite support other common datatypes like int _______________________________________________________________________________________________________________________________
#
#
#
#
#
# ## Question 2
#
# Explain the relationship between **Primary Keys** and **Foreign Keys**.
#
# Type your answer below this line:
# primary keys in a table uniquely identify a row. foreign keys is not the primary key of a particular table, but a key in another table that can be used as a key in joining. e.g. in a table with sales employees of a company, the employee number would be the primary key, and the employee number in the customer table would be a foreign key that is unlikely to uniquely identify each row because each salesperson is likely to have multiple customers. _______________________________________________________________________________________________________________________________
#
#
#
#
# ## Question 3
#
# Explain the different types of relationships entities can have in a SQL database.
#
# Type your answer below this line:
# _______________________________________________________________________________________________________________________________
#
#
# ## Question 4
#
# Explain the various types of JOINs possible with SQL.
#
# Type your answer below this line:
# inner join (default): intersaction between two tables, i.e. only rows with entries and key in both tables will be joined.
# left join: only rows with entries in the left table will be joined
# left outer join: only rows with entries in the left table that doesn't have entries in the right table will be joined
# outer join: all entries from left and right table will be joiend.
# _______________________________________________________________________________________________________________________________
#
#
#
# ## Question 5
#
# Explain the relationship between Aggregate functions and GROUP BY statements.
#
# Type your answer below this line:
# aggregate functions with group by statements return the values of a variable aggregated by the groups specified in the group by statement. e.g. in a table with gender and salary, sum(salary) group by (gender) will return the aggregate salary of each gender group
# _______________________________________________________________________________________________________________________________
#
#
#
# ## Question 6
#
# What role do Associative Entities play (JOIN Tables) in many-to-many JOINs?
#
#
# Type your answer below this line:
# in a many to many join, multiple entries in one table are joined by multiple entries in another table, causing the resulting set size to
# _______________________________________________________________________________________________________________________________
#
#
#
# ## Summary
#
# In this lesson, we practiced answering open-ended interview questions for SQL and Relational Databases.
